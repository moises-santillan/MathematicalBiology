# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %% [markdown]
# # Modelo de Lotka Volterra para poblaciones en competencia por recursos
#
# Las ecuaciones diferenciales de este modelo son:
# $$
# \frac{d x}{d t} = x \left( 1 - x - \alpha y \right) \\
# \frac{d y}{d t} = \rho y  \left( 1 - y - \beta x\right)
# $$
#
# En este modelo siempre existen 3 puntos fijos $(0, 0)$, $(0, 1)$ y $(1, 0)$. Puede existir un cuarto punto fijo $\left( \frac{1 - \alpha}{1 - \alpha \beta}, \frac{1 - \beta}{1 - \alpha \beta} \right)$, pero sólo si $\alpha, \beta < 1$ o si $\alpha, \beta > 1$.
#
# En cuanto a la estabilidad de los puntos fijos:
#
# * El punto fijo $(0, 0)$ es siempre inestable.
#
# * El punto fijo $(0, 1)$ Es estable si $\alpha > 1$
#
# * El punto fijo $(1, 0)$ Es estable si $\beta > 1$
#
# * El punto fijo $\left( \frac{1 - \alpha}{1 - \alpha \beta}, \frac{1 - \beta}{1 - \alpha \beta} \right)$ Es estable si $\alpha, \beta < 1$

# %%
def modelo(p, t, alpha, beta, rho):
    x, y = p
    dx = x * (1 - x - alpha * y)
    dy = rho * y * (1 - y - beta * x)
    return dx, dy

# %%
alpha = .5
beta = .5
rho = 1.3

t = np.linspace(0, 100, 20000)

p0 = [0.0001, 0.0001]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")


p0 = [0.001, 0.0001]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [0.002, 0.0001]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [0.005, 0.0001]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [0.01, 0.0001]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")


p0 = [0.0001, 0.001]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [0.0001, 0.002]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [0.0001, 0.005]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [0.0001, 0.01]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")


p0 = [2, 0.01]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [2, 0.1]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [2, 0.2]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [2, 0.4]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [2, 0.8]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")


p0 = [0.01,2]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [0.1, 2]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [0.2, 2]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [0.4, 2]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [0.8, 2]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

plt.plot([0, 0, 1, (1 - alpha)/(1 - alpha*beta)], [0, 1, 0, (1 - beta)/(1 - alpha*beta)], 'o', color="C1")

# %%
alpha = 1.5
beta = .5
rho = 2

t = np.linspace(0, 100, 20000)


plt.plot([0, 0, 1], [0, 1, 0], 'o', color="C1")


p0 = [0.0001, 0.0001]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [0.0002, 0.0001]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [0.0005, 0.0001]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [0.001, 0.0001]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [0.01, 0.0001]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")


p0 = [0.0001, 0.0001]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [2, 0.01]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [2, 0.1]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [2, 0.2]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [2, 0.4]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

# %%
alpha = 1.5
beta = 1.5
rho = 1*1.5

t = np.linspace(0, 100, 20000)


plt.plot([0, 0, 1, (1 - alpha)/(1 - alpha*beta)], [0, 1, 0, (1 - beta)/(1 - alpha*beta)], 'o', color="C1")


p0 = [0.0001, 0.0001]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")


p0 = [0.00011, 0.0001]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [0.0002, 0.0001]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [0.0005, 0.0001]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [0.001, 0.0001]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [0.01, 0.0001]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")


p0 = [0.0001,0.00011]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [0.0001, 0.0002]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [0.0001, 0.0005]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [0.0001, 0.001]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [0.0001, 0.01]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")


p0 = [1.5, 1.5]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")


p0 = [1.45, 1.5]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [1.3, 1.5]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [1.1, 1.5]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [.9, 1.5]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")


p0 = [1.5, 1.45]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [1.5, 1.3]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [1.5, 1.1]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [1.5, .9]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")

p0 = [1.5, .7]
p = odeint(modelo, p0, t, args=(alpha, beta, rho))
plt.plot(p[:, 0], p[:, 1], color="C0")
