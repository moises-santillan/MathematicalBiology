# %%
using Random
using Plots

# %%
N = 200
Pinit = 100000
dp = 0.05
x = ones(Pinit)
Pop = zeros(N)
Pop[1] = Pinit
for i = 2:N
    y = rand(Pinit)
    idx = findall(y .< dp)
    x[idx] .= 0
    Pop[i] = sum(x)
end

plot(Pop, yaxis=:log)

# %%
N = 200
Pinit = 100000
dp = 0.05
x = zeros(N, Pinit)
x[1, :] .= 1
for i = 2:N
    y = rand(Pinit)
    idx = findall(y .< dp)
    x[i, :] = x[i-1, :]
    x[i, idx] .= 0
end

Pop = sum(x, dims=2)

plot(Pop, yaxis=:log)

# %%
lifeTimes = sum(x, dims=1)
histogram(lifeTimes[1,:], bins = 20,  yaxis=:log)
