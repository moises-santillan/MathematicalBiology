# %%
using Random
using Plots

# %%
N = 200
Pinit = 100000
dp = 0.05
x = ones(Pinit)
Pop = zeros(N)
Pop[1] = Pinit
for i = 2:N
    y = rand(Pinit)
    idx = findall(y .< dp)
    x[idx] .= 0
    Pop[i] = sum(x)
end

# %%
plot(Pop, yaxis=:log)
